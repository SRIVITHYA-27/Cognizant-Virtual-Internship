# %% [markdown]
# # ***COGNIZANT ARTIFICIAL INTELLIGENCE***
# ***TASK 1- EXPLORATORY DATA ANALYSIS***

# %% [markdown]
# First, we need to import necessary libraries, then load csv data directly
# enter the file name or else copy the path from the file.

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **DATA LOADING**

# %%
#In order to view, analyse and manipulate the dataset, we must load it into  something called a dataframe, 
#which is a way of storing tabulated data in a virtual table. This dataframe will allow us to analyse the data freely. 
#To load it into a dataframe, we will need a package called Pandas.
df = pd.read_csv("sample_sales_data.csv")

# %%
df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')

# %%
df.head() # methods allows us to see top 5 rows within in dataframe
# Out:
#                          transaction_id            timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
# Descriptive Statistics
df.describe()
# Out:
#         unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000
# mean      7.819480     2.501597    19.709905
# std       5.388088     1.122722    17.446680
# min       0.190000     1.000000     0.190000
# 25%       3.990000     1.000000     6.570000
# 50%       7.190000     3.000000    14.970000
# 75%      11.190000     4.000000    28.470000
# max      23.990000     4.000000    95.960000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7829 entries, 0 to 7828
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  7829 non-null   object
#  1   timestamp       7829 non-null   object
#  2   product_id      7829 non-null   object
#  3   category        7829 non-null   object
#  4   customer_type   7829 non-null   object
#  5   unit_price      7829 non-null   float64
#  6   quantity        7829 non-null   int64
#  7   total           7829 non-null   float64
#  8   payment_type    7829 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 550.6+ KB

# %% [markdown]
# # BOX PLOT

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # HISTOGRAM

# %%
df.plot(kind='hist', bins=10 )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Data Visualization
# Now i have been computed descriptive statistics of the dataset, then have to create some visualizations.
# For Visualization,i have used seasborn package.

# %%
def plot_continuous_distribution(data: pd.DataFrame = None, column: list = None, height: int = 5):
  for i in column:
    sns.displot(data, x=i, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

def get_unique_values(data, column):
  num_unique_values = len(data[column].unique())
  value_counts = data[column].value_counts()
  print(f"Column: {column} has {num_unique_values} unique values\n")
  print(value_counts)

def plot_categorical_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8, aspect: int = 2):
  _ = sns.catplot(data=data, x=column, kind='count', height=height, aspect=aspect).set(title=f'Distribution of {column}');

def correlation_plot(data: pd.DataFrame = None):
  corr = data.corr()
  sns.heatmap(corr, cmap='coolwarm', annot=True, square=True)

# %%
plot_continuous_distribution(df, ['unit_price','quantity','total'])

# %%
#correlation plot
correlation_plot(df)

# %%
corr = df.corr()
corr.style.background_gradient(cmap= 'coolwarm')
# Out:
# <style type="text/css">
# #T_3beab_row0_col0, #T_3beab_row1_col1, #T_3beab_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3beab_row0_col1, #T_3beab_row1_col0, #T_3beab_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3beab_row0_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_3beab_row2_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_3beab_row2_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# </style>
# <table id="T_3beab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3beab_level0_col0" class="col_heading level0 col0" >unit_price</th>
#       <th id="T_3beab_level0_col1" class="col_heading level0 col1" >quantity</th>
#       <th id="T_3beab_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3beab_level0_row0" class="row_heading level0 row0" >unit_price</th>
# ...

# %%
plt.figure(figsize = [10, 6])
sns.countplot(x = df['customer_type'])
sns.countplot(x = df['customer_type']).set_xticklabels(sns.countplot(x = df['customer_type']).get_xticklabels(), rotation = 90, ha = 'right')
plt.title('Type of Customer')
# Out:
# Text(0.5, 1.0, 'Type of Customer')

# %%
plt.figure(figsize = [10, 6])
sns.countplot(x = df['category'])
sns.countplot(x = df['category']).set_xticklabels(sns.countplot(x = df['category']).get_xticklabels(), rotation = 90, ha = 'right')
plt.title('Category of Product')
# Out:
# Text(0.5, 1.0, 'Category of Product')

# %%
plt.figure(figsize = [10, 6])
sns.countplot(x = df['payment_type'])
sns.countplot(x = df['payment_type']).set_xticklabels(sns.countplot(x = df['payment_type']).get_xticklabels(), rotation = 90, ha = 'right')
plt.title('Mode Of Payment')
# Out:
# Text(0.5, 1.0, 'Mode Of Payment')

# %% [markdown]
# # Section 5 - Summary

# %% [markdown]
#  I have completed an initial exploratory data analysis on the sales_data set. I have a solid understanding of the data.
# The clients wants to know
#
#     *** "How to Better stock the items that they sell" ***
#
# From this dataset, it is impossible to answer that question. In order to make the next step on this project with the client, it is clear that:
#
# We need more rows of data. The current sample is only from 1 store and 1 week worth of data
# We need to frame the specific problem statement that we want to solve. The current business problem is too broad, we should narrow down the focus in order to deliver a valuable end product
# We need more features. Based on the problem statement that we move forward with, we need more columns (features) that may help us to understand the outcome that we're solving for
